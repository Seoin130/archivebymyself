# %%
import pandas as pd

# %% [markdown]
# # 상선 내선 평일

# %%
df1=pd.read_csv('upperinner_weekday.csv')

# %%
df1["6시00분"].max()
# Out:
# 52.6

# %%
print("평일 6시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["6시00분"].max(), "입니다.")
# Out:
# 평일 6시00분 상선 혹은 내선 열차의 최대 혼잡도는  52.6 입니다.

# %%
df1.loc[df1['6시00분']==df1["6시00분"].max()]
# Out:
#     조사일자  호선     역명  구분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  \
# 243   평일   7  총신대입구  상선   52.6   47.1   61.5   74.7  103.7   74.1   77.9
#
#      18시00분  18시30분  19시00분  19시30분  20시00분
# 243    35.9    36.2    24.3    19.8    19.4

# %%
print("평일 6시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["6시30분"].max(), "입니다.")
# Out:
# 평일 6시30분 상선 혹은 내선 열차의 최대 혼잡도는  64.5 입니다.

# %%
print("평일 7시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["7시00분"].max(), "입니다.")
# Out:
# 평일 7시00분 상선 혹은 내선 열차의 최대 혼잡도는  71.7 입니다.

# %%
df1.loc[[243], ["조사일자", "호선", "역명", "구분", "6시00분"]]
# Out:
#     조사일자  호선     역명  구분  6시00분
# 243   평일   7  총신대입구  상선   52.6

# %%
print("평일 7시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["7시30분"].max(), "입니다.")
print("평일 8시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["8시00분"].max(), "입니다.")
print("평일 8시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["8시30분"].max(), "입니다.")
print("평일 9시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["9시00분"].max(), "입니다.")
print("평일 18시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["18시00분"].max(), "입니다.")
print("평일 18시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["18시30분"].max(), "입니다.")
print("평일 19시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["19시00분"].max(), "입니다.")
print("평일 19시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["19시30분"].max(), "입니다.")
print("평일 20시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df1["20시00분"].max(), "입니다.")
# Out:
# 평일 7시30분 상선 혹은 내선 열차의 최대 혼잡도는  96.7 입니다.
# 평일 8시00분 상선 혹은 내선 열차의 최대 혼잡도는  132.2 입니다.
# 평일 8시30분 상선 혹은 내선 열차의 최대 혼잡도는  104.1 입니다.
# 평일 9시00분 상선 혹은 내선 열차의 최대 혼잡도는  97.9 입니다.
# 평일 18시00분 상선 혹은 내선 열차의 최대 혼잡도는  131.7 입니다.
# 평일 18시30분 상선 혹은 내선 열차의 최대 혼잡도는  126.2 입니다.
# 평일 19시00분 상선 혹은 내선 열차의 최대 혼잡도는  94.5 입니다.
# 평일 19시30분 상선 혹은 내선 열차의 최대 혼잡도는  66.2 입니다.
# 평일 20시00분 상선 혹은 내선 열차의 최대 혼잡도는  60.5 입니다.

# %% [markdown]
# # 상선 내선 토요일

# %%
df2=pd.read_csv('upperinner_saturday.csv')

# %%
print("토요일 6시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["6시00분"].max(), "입니다.")
print("토요일 6시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["6시30분"].max(), "입니다.")
print("토요일 7시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["7시00분"].max(), "입니다.")
print("토요일 7시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["7시30분"].max(), "입니다.")
print("토요일 8시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["8시00분"].max(), "입니다.")
print("토요일 8시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["8시30분"].max(), "입니다.")
print("토요일 9시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["9시00분"].max(), "입니다.")
print("토요일 18시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["18시00분"].max(), "입니다.")
print("토요일 18시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["18시30분"].max(), "입니다.")
print("토요일 19시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["19시00분"].max(), "입니다.")
print("토요일 19시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["19시30분"].max(), "입니다.")
print("토요일 20시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df2["20시00분"].max(), "입니다.")
# Out:
# 토요일 6시00분 상선 혹은 내선 열차의 최대 혼잡도는  44.0 입니다.
# 토요일 6시30분 상선 혹은 내선 열차의 최대 혼잡도는  31.1 입니다.
# 토요일 7시00분 상선 혹은 내선 열차의 최대 혼잡도는  27.7 입니다.
# 토요일 7시30분 상선 혹은 내선 열차의 최대 혼잡도는  35.2 입니다.
# 토요일 8시00분 상선 혹은 내선 열차의 최대 혼잡도는  49.6 입니다.
# 토요일 8시30분 상선 혹은 내선 열차의 최대 혼잡도는  49.6 입니다.
# 토요일 9시00분 상선 혹은 내선 열차의 최대 혼잡도는  56.2 입니다.
# 토요일 18시00분 상선 혹은 내선 열차의 최대 혼잡도는  74.2 입니다.
# 토요일 18시30분 상선 혹은 내선 열차의 최대 혼잡도는  75.1 입니다.
# 토요일 19시00분 상선 혹은 내선 열차의 최대 혼잡도는  63.7 입니다.
# 토요일 19시30분 상선 혹은 내선 열차의 최대 혼잡도는  54.0 입니다.
# 토요일 20시00분 상선 혹은 내선 열차의 최대 혼잡도는  58.9 입니다.

# %% [markdown]
# # 상선 내선 일요일

# %%
df3=pd.read_csv('upperinner_sunday.csv')

# %%
print("일요일 6시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["6시00분"].max(), "입니다.")
print("일요일 6시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["6시30분"].max(), "입니다.")
print("일요일 7시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["7시00분"].max(), "입니다.")
print("일요일 7시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["7시30분"].max(), "입니다.")
print("일요일 8시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["8시00분"].max(), "입니다.")
print("일요일 8시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["8시30분"].max(), "입니다.")
print("일요일 9시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["9시00분"].max(), "입니다.")
print("일요일 18시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["18시00분"].max(), "입니다.")
print("일요일 18시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["18시30분"].max(), "입니다.")
print("일요일 19시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["19시00분"].max(), "입니다.")
print("일요일 19시30분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["19시30분"].max(), "입니다.")
print("일요일 20시00분 상선 혹은 내선 열차의 최대 혼잡도는 ", df3["20시00분"].max(), "입니다.")
# Out:
# 일요일 6시00분 상선 혹은 내선 열차의 최대 혼잡도는  19.6 입니다.
# 일요일 6시30분 상선 혹은 내선 열차의 최대 혼잡도는  17.3 입니다.
# 일요일 7시00분 상선 혹은 내선 열차의 최대 혼잡도는  15.6 입니다.
# 일요일 7시30분 상선 혹은 내선 열차의 최대 혼잡도는  21.0 입니다.
# 일요일 8시00분 상선 혹은 내선 열차의 최대 혼잡도는  28.1 입니다.
# 일요일 8시30분 상선 혹은 내선 열차의 최대 혼잡도는  28.6 입니다.
# 일요일 9시00분 상선 혹은 내선 열차의 최대 혼잡도는  33.8 입니다.
# 일요일 18시00분 상선 혹은 내선 열차의 최대 혼잡도는  55.9 입니다.
# 일요일 18시30분 상선 혹은 내선 열차의 최대 혼잡도는  53.8 입니다.
# 일요일 19시00분 상선 혹은 내선 열차의 최대 혼잡도는  47.8 입니다.
# 일요일 19시30분 상선 혹은 내선 열차의 최대 혼잡도는  43.2 입니다.
# 일요일 20시00분 상선 혹은 내선 열차의 최대 혼잡도는  43.6 입니다.

# %% [markdown]
# # 하선 외선 평일

# %%
df4=pd.read_csv('lowerouter_weekday.csv')

# %%
print("평일 6시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["6시00분"].max(), "입니다.")
print("평일 6시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["6시30분"].max(), "입니다.")
print("평일 7시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["7시00분"].max(), "입니다.")
print("평일 7시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["7시30분"].max(), "입니다.")
print("평일 8시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["8시00분"].max(), "입니다.")
print("평일 8시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["8시30분"].max(), "입니다.")
print("평일 9시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["9시00분"].max(), "입니다.")
print("평일 18시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["18시00분"].max(), "입니다.")
print("평일 18시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["18시30분"].max(), "입니다.")
print("평일 19시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["19시00분"].max(), "입니다.")
print("평일 19시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["19시30분"].max(), "입니다.")
print("평일 20시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df4["20시00분"].max(), "입니다.")
# Out:
# 평일 6시00분 하선 혹은 외선 열차의 최대 혼잡도는  56.5 입니다.
# 평일 6시30분 하선 혹은 외선 열차의 최대 혼잡도는  66.8 입니다.
# 평일 7시00분 하선 혹은 외선 열차의 최대 혼잡도는  93.4 입니다.
# 평일 7시30분 하선 혹은 외선 열차의 최대 혼잡도는  107.9 입니다.
# 평일 8시00분 하선 혹은 외선 열차의 최대 혼잡도는  150.8 입니다.
# 평일 8시30분 하선 혹은 외선 열차의 최대 혼잡도는  149.4 입니다.
# 평일 9시00분 하선 혹은 외선 열차의 최대 혼잡도는  123.8 입니다.
# 평일 18시00분 하선 혹은 외선 열차의 최대 혼잡도는  119.9 입니다.
# 평일 18시30분 하선 혹은 외선 열차의 최대 혼잡도는  121.7 입니다.
# 평일 19시00분 하선 혹은 외선 열차의 최대 혼잡도는  86.3 입니다.
# 평일 19시30분 하선 혹은 외선 열차의 최대 혼잡도는  70.4 입니다.
# 평일 20시00분 하선 혹은 외선 열차의 최대 혼잡도는  61.7 입니다.

# %% [markdown]
# # 하선 외선 토요일

# %%
df5=pd.read_csv('lowerouter_saturday.csv')

# %%
print("토요일 6시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["6시00분"].max(), "입니다.")
print("토요일 6시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["6시30분"].max(), "입니다.")
print("토요일 7시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["7시00분"].max(), "입니다.")
print("토요일 7시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["7시30분"].max(), "입니다.")
print("토요일 8시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["8시00분"].max(), "입니다.")
print("토요일 8시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["8시30분"].max(), "입니다.")
print("토요일 9시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["9시00분"].max(), "입니다.")
print("토요일 18시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["18시00분"].max(), "입니다.")
print("토요일 18시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["18시30분"].max(), "입니다.")
print("토요일 19시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["19시00분"].max(), "입니다.")
print("토요일 19시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["19시30분"].max(), "입니다.")
print("토요일 20시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df5["20시00분"].max(), "입니다.")
# Out:
# 토요일 6시00분 하선 혹은 외선 열차의 최대 혼잡도는  46.5 입니다.
# 토요일 6시30분 하선 혹은 외선 열차의 최대 혼잡도는  37.6 입니다.
# 토요일 7시00분 하선 혹은 외선 열차의 최대 혼잡도는  36.0 입니다.
# 토요일 7시30분 하선 혹은 외선 열차의 최대 혼잡도는  42.8 입니다.
# 토요일 8시00분 하선 혹은 외선 열차의 최대 혼잡도는  58.9 입니다.
# 토요일 8시30분 하선 혹은 외선 열차의 최대 혼잡도는  61.5 입니다.
# 토요일 9시00분 하선 혹은 외선 열차의 최대 혼잡도는  69.0 입니다.
# 토요일 18시00분 하선 혹은 외선 열차의 최대 혼잡도는  57.8 입니다.
# 토요일 18시30분 하선 혹은 외선 열차의 최대 혼잡도는  51.8 입니다.
# 토요일 19시00분 하선 혹은 외선 열차의 최대 혼잡도는  47.5 입니다.
# 토요일 19시30분 하선 혹은 외선 열차의 최대 혼잡도는  41.0 입니다.
# 토요일 20시00분 하선 혹은 외선 열차의 최대 혼잡도는  44.0 입니다.

# %% [markdown]
# # 하선 외선 일요일

# %%
df6=pd.read_csv('lowerouter_sunday.csv')

# %%
print("일요일 6시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["6시00분"].max(), "입니다.")
print("일요일 6시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["6시30분"].max(), "입니다.")
print("일요일 7시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["7시00분"].max(), "입니다.")
print("일요일 7시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["7시30분"].max(), "입니다.")
print("일요일 8시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["8시00분"].max(), "입니다.")
print("일요일 8시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["8시30분"].max(), "입니다.")
print("일요일 9시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["9시00분"].max(), "입니다.")
print("일요일 18시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["18시00분"].max(), "입니다.")
print("일요일 18시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["18시30분"].max(), "입니다.")
print("일요일 19시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["19시00분"].max(), "입니다.")
print("일요일 19시30분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["19시30분"].max(), "입니다.")
print("일요일 20시00분 하선 혹은 외선 열차의 최대 혼잡도는 ", df6["20시00분"].max(), "입니다.")
# Out:
# 일요일 6시00분 하선 혹은 외선 열차의 최대 혼잡도는  25.8 입니다.
# 일요일 6시30분 하선 혹은 외선 열차의 최대 혼잡도는  20.3 입니다.
# 일요일 7시00분 하선 혹은 외선 열차의 최대 혼잡도는  18.8 입니다.
# 일요일 7시30분 하선 혹은 외선 열차의 최대 혼잡도는  23.3 입니다.
# 일요일 8시00분 하선 혹은 외선 열차의 최대 혼잡도는  31.5 입니다.
# 일요일 8시30분 하선 혹은 외선 열차의 최대 혼잡도는  33.0 입니다.
# 일요일 9시00분 하선 혹은 외선 열차의 최대 혼잡도는  41.3 입니다.
# 일요일 18시00분 하선 혹은 외선 열차의 최대 혼잡도는  46.2 입니다.
# 일요일 18시30분 하선 혹은 외선 열차의 최대 혼잡도는  42.2 입니다.
# 일요일 19시00분 하선 혹은 외선 열차의 최대 혼잡도는  37.7 입니다.
# 일요일 19시30분 하선 혹은 외선 열차의 최대 혼잡도는  34.8 입니다.
# 일요일 20시00분 하선 혹은 외선 열차의 최대 혼잡도는  40.1 입니다.

# %% [markdown]
# # 그래프 작성

# %%
#상선내선 평일 그래프
import matplotlib.pyplot as plt
import numpy as np
time=["6:00", "6:30", "7:00", "7:30", "8:00", "8:30", "9:00", "18:00", "18:30", "19:00", "19:30", "20:00"]
business=[52.6, 64.5, 71.7, 96.7, 132.2, 104.1, 97.9, 131.7, 126.2, 94.5, 66.2, 60.5]
x=np.arange(12)
plt.figure(figsize=(20, 15))
plt.rc('font', size=20)
plt.bar(x, business)
plt.xticks(x, time)
plt.grid(True, axis='y')
plt.title("Degree of Congestion in Upper and Inner Lines on Weekdays")
plt.show()

# %%
#상선내선 토요일 그래프
import matplotlib.pyplot as plt
import numpy as np
time=["6:00", "6:30", "7:00", "7:30", "8:00", "8:30", "9:00", "18:00", "18:30", "19:00", "19:30", "20:00"]
business=[44.0, 31.1, 27.7, 35.2, 49.6, 49.6, 56.2, 74.2, 75.1, 63.7, 54.0, 58.9]
x=np.arange(12)
plt.figure(figsize=(20, 15))
plt.rc('font', size=20)
plt.bar(x, business)
plt.xticks(x, time)
plt.grid(True, axis='y')
plt.title("Degree of Congestion in Upper and Inner Lines on Saturdays")
plt.show()

# %%
#상선내선 일요일 그래프
import matplotlib.pyplot as plt
import numpy as np
time=["6:00", "6:30", "7:00", "7:30", "8:00", "8:30", "9:00", "18:00", "18:30", "19:00", "19:30", "20:00"]
business=[19.6, 17.3, 15.6, 21.0, 28.1, 28.6, 33.8, 55.9, 53.8, 47.8, 43.2, 43.6]
x=np.arange(12)
plt.figure(figsize=(20, 15))
plt.rc('font', size=20)
plt.bar(x, business)
plt.xticks(x, time)
plt.grid(True, axis='y')
plt.title("Degree of Congestion in Upper and Inner Lines on Sundays")
plt.show()

# %%
#하선외선 평일 그래프
import matplotlib.pyplot as plt
import numpy as np
time=["6:00", "6:30", "7:00", "7:30", "8:00", "8:30", "9:00", "18:00", "18:30", "19:00", "19:30", "20:00"]
business=[56.5, 66.8, 93.4, 107.9, 150.8, 149.4, 123.8, 119.9, 121.7, 86.3, 70.4, 61.7]
x=np.arange(12)
plt.figure(figsize=(20, 15))
plt.rc('font', size=20)
plt.bar(x, business)
plt.xticks(x, time)
plt.grid(True, axis='y')
plt.title("Degree of Congestion in Lower and Outer Lines on Weekdays")
plt.show()

# %%
#하선외산 토요일 그래프
import matplotlib.pyplot as plt
import numpy as np
time=["6:00", "6:30", "7:00", "7:30", "8:00", "8:30", "9:00", "18:00", "18:30", "19:00", "19:30", "20:00"]
business=[46.5, 37.6, 36.0, 42.8, 58.9, 61.5, 69.0, 57.8, 51.8, 47.5, 41.0, 44.0]
x=np.arange(12)
plt.figure(figsize=(20, 15))
plt.rc('font', size=20)
plt.bar(x, business)
plt.xticks(x, time)
plt.grid(True, axis='y')
plt.title("Degree of Congestion in Lower and Outer Lines on Saturdays")
plt.show()

# %%
#하선외선 일요일 그래프
import matplotlib.pyplot as plt
import numpy as np
time=["6:00", "6:30", "7:00", "7:30", "8:00", "8:30", "9:00", "18:00", "18:30", "19:00", "19:30", "20:00"]
business=[25.8, 20.3, 18.8, 23.3, 31.5, 33.0, 41.3, 46.2, 42.2, 37.7, 34.8, 40.1]
x=np.arange(12)
plt.figure(figsize=(20, 15))
plt.rc('font', size=20)
plt.bar(x, business)
plt.xticks(x, time)
plt.grid(True, axis='y')
plt.title("Degree of Congestion in Lower and Outer Lines on Sundays")
plt.show()

# %% [markdown]
# # 혼잡도 계산하는 소스코드

# %%
class GivingOptions:
    def Choosing(self):
        linechoose=input("상선내선 혹은 하선외선 중 찾고자 하는 노선을 적어주세요.: ")
        if linechoose=='상선내선':
            daychoose=input("평일, 토요일, 일요일 중 찾고자 하는 기간을 적어주세요: ")
            if daychoose=='평일':
                finalchoose=Congestion_UpperWeekday()
                return finalchoose.TimeSelection_UpperWeekday()
            if daychoose=='토요일':
                finalchoose=Congestion_UpperSaturday()
                return finalchoose.TimeSelection_UpperSaturday()
            if daychoose=='일요일':
                finalchoose=Congestion_UpperSunday()
                return finalchoose.TimeSelection_UpperSunday()
        if linechoose=='하선외선':
            daychoose=input("평일, 토요일, 일요일 중 찾고자 하는 기간을 적어주세요: ")
            if daychoose=='평일':
                finalchoose=Congestion_LowerWeekday()
                return finalchoose.TimeSelection_UpperWeekday()
            if daychoose=='토요일':
                finalchoose=Congestion_LowerSaturday()
                return finalchoose.TimeSelection_UpperSaturday()
            if daychoose=='일요일':
                finalchoose=Congestion_LowerSunday()
                return finalchoose.TimeSelection_UpperSunday()

# %%
class Congestion_UpperWeekday:
    def TimeSelection_UpperWeekday(self):
        linetime=input("운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.\n운행 시간대를 입력하세요 \n 시간대는 0시00분 형태로 입력해주세요: ")
        if linetime=='6시00분':
            print(linetime, "최대 혼잡도는", df1["6시00분"].max(), "입니다.")
        elif linetime=='6시30분':
            print(linetime, "최대 혼잡도는", df1["6시30분"].max(), "입니다.")
        elif linetime=='7시00분':
            print(linetime, "최대 혼잡도는", df1["7시00분"].max(), "입니다.")
        elif linetime=='7시30분':
            print(linetime, "최대 혼잡도는", df1["7시30분"].max(), "입니다.")
        elif linetime=='8시00분':
            print(linetime, "최대 혼잡도는", df1["8시00분"].max(), "입니다.")
        elif linetime=='8시30분':
            print(linetime, "최대 혼잡도는", df1["8시30분"].max(), "입니다.")
        elif linetime=='9시00분':
            print(linetime, "최대 혼잡도는", df1["9시00분"].max(), "입니다.")
        elif linetime=='18시00분':
            print(linetime, "최대 혼잡도는", df1["18시00분"].max(), "입니다.")
        elif linetime=='18시30분':
            print(linetime, "최대 혼잡도는", df1["18시30분"].max(), "입니다.")
        elif linetime=='19시00분':
            print(linetime, "최대 혼잡도는", df1["19시00분"].max(), "입니다.")
        elif linetime=='19시30분':
            print(linetime, "최대 혼잡도는", df1["19시30분"].max(), "입니다.")
        elif linetime=='20시00분':
            print(linetime, "최대 혼잡도는", df1["20시00분"].max(), "입니다.")
        else:
            print("해당 시간대에 대한 정보가 없습니다.")

# %%
class Congestion_UpperSaturday:
    def TimeSelection_UpperSaturday(self):
        linetime=input("운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.\n운행 시간대를 입력하세요 \n 시간대는 0시00분 형태로 입력해주세요: ")
        if linetime=='6시00분':
            print(linetime, "최대 혼잡도는", df2["6시00분"].max(), "입니다.")
        elif linetime=='6시30분':
            print(linetime, "최대 혼잡도는", df2["6시30분"].max(), "입니다.")
        elif linetime=='7시00분':
            print(linetime, "최대 혼잡도는", df2["7시00분"].max(), "입니다.")
        elif linetime=='7시30분':
            print(linetime, "최대 혼잡도는", df2["7시30분"].max(), "입니다.")
        elif linetime=='8시00분':
            print(linetime, "최대 혼잡도는", df2["8시00분"].max(), "입니다.")
        elif linetime=='8시30분':
            print(linetime, "최대 혼잡도는", df2["8시30분"].max(), "입니다.")
        elif linetime=='9시00분':
            print(linetime, "최대 혼잡도는", df2["9시00분"].max(), "입니다.")
        elif linetime=='18시00분':
            print(linetime, "최대 혼잡도는", df2["18시00분"].max(), "입니다.")
        elif linetime=='18시30분':
            print(linetime, "최대 혼잡도는", df2["18시30분"].max(), "입니다.")
        elif linetime=='19시00분':
            print(linetime, "최대 혼잡도는", df2["19시00분"].max(), "입니다.")
        elif linetime=='19시30분':
            print(linetime, "최대 혼잡도는", df2["19시30분"].max(), "입니다.")
        elif linetime=='20시00분':
            print(linetime, "최대 혼잡도는", df2["20시00분"].max(), "입니다.")
        else:
            print("해당 시간대에 대한 정보가 없습니다.")

# %%
class Congestion_UpperSunday:
    def TimeSelection_UpperSunday(self):
        linetime=input("운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.\n운행 시간대를 입력하세요 \n 시간대는 0시00분 형태로 입력해주세요: ")
        if linetime=='6시00분':
            print(linetime, "최대 혼잡도는", df3["6시00분"].max(), "입니다.")
        elif linetime=='6시30분':
            print(linetime, "최대 혼잡도는", df3["6시30분"].max(), "입니다.")
        elif linetime=='7시00분':
            print(linetime, "최대 혼잡도는", df3["7시00분"].max(), "입니다.")
        elif linetime=='7시30분':
            print(linetime, "최대 혼잡도는", df3["7시30분"].max(), "입니다.")
        elif linetime=='8시00분':
            print(linetime, "최대 혼잡도는", df3["8시00분"].max(), "입니다.")
        elif linetime=='8시30분':
            print(linetime, "최대 혼잡도는", df3["8시30분"].max(), "입니다.")
        elif linetime=='9시00분':
            print(linetime, "최대 혼잡도는", df3["9시00분"].max(), "입니다.")
        elif linetime=='18시00분':
            print(linetime, "최대 혼잡도는", df3["18시00분"].max(), "입니다.")
        elif linetime=='18시30분':
            print(linetime, "최대 혼잡도는", df3["18시30분"].max(), "입니다.")
        elif linetime=='19시00분':
            print(linetime, "최대 혼잡도는", df3["19시00분"].max(), "입니다.")
        elif linetime=='19시30분':
            print(linetime, "최대 혼잡도는", df3["19시30분"].max(), "입니다.")
        elif linetime=='20시00분':
            print(linetime, "최대 혼잡도는", df3["20시00분"].max(), "입니다.")
        else:
            print("해당 시간대에 대한 정보가 없습니다.")

# %%
class Congestion_LowerWeekday:
    def TimeSelection_LowerWeekday(self):
        linetime=input("운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.\n운행 시간대를 입력하세요 \n 시간대는 0시00분 형태로 입력해주세요: ")
        if linetime=='6시00분':
            print(linetime, "최대 혼잡도는", df4["6시00분"].max(), "입니다.")
        elif linetime=='6시30분':
            print(linetime, "최대 혼잡도는", df4["6시30분"].max(), "입니다.")
        elif linetime=='7시00분':
            print(linetime, "최대 혼잡도는", df4["7시00분"].max(), "입니다.")
        elif linetime=='7시30분':
            print(linetime, "최대 혼잡도는", df4["7시30분"].max(), "입니다.")
        elif linetime=='8시00분':
            print(linetime, "최대 혼잡도는", df4["8시00분"].max(), "입니다.")
        elif linetime=='8시30분':
            print(linetime, "최대 혼잡도는", df4["8시30분"].max(), "입니다.")
        elif linetime=='9시00분':
            print(linetime, "최대 혼잡도는", df4["9시00분"].max(), "입니다.")
        elif linetime=='18시00분':
            print(linetime, "최대 혼잡도는", df4["18시00분"].max(), "입니다.")
        elif linetime=='18시30분':
            print(linetime, "최대 혼잡도는", df4["18시30분"].max(), "입니다.")
        elif linetime=='19시00분':
            print(linetime, "최대 혼잡도는", df4["19시00분"].max(), "입니다.")
        elif linetime=='19시30분':
            print(linetime, "최대 혼잡도는", df4["19시30분"].max(), "입니다.")
        elif linetime=='20시00분':
            print(linetime, "최대 혼잡도는", df4["20시00분"].max(), "입니다.")
        else:
            print("해당 시간대에 대한 정보가 없습니다.")

# %%
class Congestion_LowerSaturday:
    def TimeSelection_LowerSaturday(self):
        linetime=input("운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.\n운행 시간대를 입력하세요 \n 시간대는 0시00분 형태로 입력해주세요: ")
        if linetime=='6시00분':
            print(linetime, "최대 혼잡도는", df5["6시00분"].max(), "입니다.")
        elif linetime=='6시30분':
            print(linetime, "최대 혼잡도는", df5["6시30분"].max(), "입니다.")
        elif linetime=='7시00분':
            print(linetime, "최대 혼잡도는", df5["7시00분"].max(), "입니다.")
        elif linetime=='7시30분':
            print(linetime, "최대 혼잡도는", df5["7시30분"].max(), "입니다.")
        elif linetime=='8시00분':
            print(linetime, "최대 혼잡도는", df5["8시00분"].max(), "입니다.")
        elif linetime=='8시30분':
            print(linetime, "최대 혼잡도는", df5["8시30분"].max(), "입니다.")
        elif linetime=='9시00분':
            print(linetime, "최대 혼잡도는", df5["9시00분"].max(), "입니다.")
        elif linetime=='18시00분':
            print(linetime, "최대 혼잡도는", df5["18시00분"].max(), "입니다.")
        elif linetime=='18시30분':
            print(linetime, "최대 혼잡도는", df5["18시30분"].max(), "입니다.")
        elif linetime=='19시00분':
            print(linetime, "최대 혼잡도는", df5["19시00분"].max(), "입니다.")
        elif linetime=='19시30분':
            print(linetime, "최대 혼잡도는", df5["19시30분"].max(), "입니다.")
        elif linetime=='20시00분':
            print(linetime, "최대 혼잡도는", df5["20시00분"].max(), "입니다.")
        else:
            print("해당 시간대에 대한 정보가 없습니다.")

# %%
class Congestion_LowerSunday:
    def TimeSelection_LowerSunday(self):
        linetime=input("운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.\n운행 시간대를 입력하세요 \n 시간대는 0시00분 형태로 입력해주세요: ")
        if linetime=='6시00분':
            print(linetime, "최대 혼잡도는", df6["6시00분"].max(), "입니다.")
        elif linetime=='6시30분':
            print(linetime, "최대 혼잡도는", df6["6시30분"].max(), "입니다.")
        elif linetime=='7시00분':
            print(linetime, "최대 혼잡도는", df6["7시00분"].max(), "입니다.")
        elif linetime=='7시30분':
            print(linetime, "최대 혼잡도는", df6["7시30분"].max(), "입니다.")
        elif linetime=='8시00분':
            print(linetime, "최대 혼잡도는", df6["8시00분"].max(), "입니다.")
        elif linetime=='8시30분':
            print(linetime, "최대 혼잡도는", df6["8시30분"].max(), "입니다.")
        elif linetime=='9시00분':
            print(linetime, "최대 혼잡도는", df6["9시00분"].max(), "입니다.")
        elif linetime=='18시00분':
            print(linetime, "최대 혼잡도는", df6["18시00분"].max(), "입니다.")
        elif linetime=='18시30분':
            print(linetime, "최대 혼잡도는", df6["18시30분"].max(), "입니다.")
        elif linetime=='19시00분':
            print(linetime, "최대 혼잡도는", df6["19시00분"].max(), "입니다.")
        elif linetime=='19시30분':
            print(linetime, "최대 혼잡도는", df6["19시30분"].max(), "입니다.")
        elif linetime=='20시00분':
            print(linetime, "최대 혼잡도는", df6["20시00분"].max(), "입니다.")
        else:
            print("해당 시간대에 대한 정보가 없습니다.")

# %%
allprogram=GivingOptions()

print(allprogram.Choosing())
# Out:
# 상선내선 혹은 하선외선 중 찾고자 하는 노선을 적어주세요.: 상선내선
# 평일, 토요일, 일요일 중 찾고자 하는 기간을 적어주세요: 토요일
# 운행 시간대는 6시00분부터 9시00분, 18시00분부터 20시00분까지 30분 단위로 있습니다.
# 운행 시간대를 입력하세요
#  시간대는 0시00분 형태로 입력해주세요: 19시00분
# 19시00분 최대 혼잡도는 63.7 입니다.
# None
